# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics
import seaborn as sns

# %%
gross_2018 = pd.read_csv('top_gross_2018', index_col = 0)
gross_2018
# Out:
#          tconst                           title  runtime_minutes  \
# 1251  tt4154756          Avengers: Infinity War            149.0
# 1193  tt3606756                   Incredibles 2            118.0
# 1310  tt4881806  Jurassic World: Fallen Kingdom            128.0
# 475   tt1477834                         Aquaman            143.0
# 1341  tt5463162                      Deadpool 2            119.0
# 1311  tt4912910   Mission: Impossible - Fallout            147.0
# 1324  tt5095030            Ant-Man and the Wasp            118.0
# 712   tt1727824               Bohemian Rhapsody            134.0
# 1220  tt3778644         Solo: A Star Wars Story            135.0
# 1364  tt5848272       Ralph Breaks the Internet            112.0
#
#                           genres  averagerating  numvotes release_date studio  \
# 1251     Action,Adventure,Sci-Fi            8.5  670926.0   2018-04-27     BV
# 1193  Action,Adventure,Animation            7.7  203510.0   2018-06-15     BV
# ...

# %%
gross_2017 = pd.read_csv('top_gross_2017', index_col = 0)
gross_2016 = pd.read_csv('top_gross_2016', index_col = 0)
gross_2015 = pd.read_csv('top_gross_2015', index_col = 0)
gross_2014 = pd.read_csv('top_gross_2014', index_col = 0)

# %%
runtime_mean18 = statistics.mean(gross_2018['runtime_minutes'].tolist())
runtime_mean17 = statistics.mean(gross_2017['runtime_minutes'].tolist())
runtime_mean16 = statistics.mean(gross_2016['runtime_minutes'].tolist())
runtime_mean15 = statistics.mean(gross_2015['runtime_minutes'].tolist())
runtime_mean14 = statistics.mean(gross_2014['runtime_minutes'].tolist())

# %% [markdown]
# ## Creating bar graph to show Run Times

# %%
## Creating lists to plot runtimes subplots to compare years
runtime_2018 = gross_2018['runtime_minutes'].tolist()
runtime_2017 = gross_2017['runtime_minutes'].tolist()
runtime_2016 = gross_2016['runtime_minutes'].tolist()
runtime_2015 = gross_2015['runtime_minutes'].tolist()
runtime_2014 = gross_2014['runtime_minutes'].tolist()
titles_2018 = gross_2018['title'].tolist()
titles_2017 = gross_2017['title'].tolist()
titles_2016 = gross_2016['title'].tolist()
titles_2015 = gross_2015['title'].tolist()
titles_2014 = gross_2014['title'].tolist()

# %%
x1 = titles_2018
x2 = titles_2017
x3 = titles_2016
x4 = titles_2015
x5 = titles_2014

plt.figure(figsize =(16, 8))
plt.subplot(2,3,1)
title18 = plt.bar(x1, runtime_2018)
plt.ylabel('Runtime in Minutes')
plt.xticks(x1, rotation = 'vertical')
plt.title('Runtimes of Top Grossing 2018 Movies')

plt.subplot(2,3,2)
title17 = plt.bar(x2, runtime_2017)
plt.ylabel('Runtime in Minutes')
plt.xticks(x2, rotation = 'vertical')
plt.title('Runtimes of Top Grossing 2017 Movies')

plt.subplot(2,3,3)
title16 = plt.bar(x3, runtime_2016)
plt.ylabel('Runtime in Minutes')
plt.xticks(x3, rotation = 'vertical')
plt.title('Runtimes of Top Grossing 2016 Movies')


plt.savefig('Runtime 2016-2018.png')
plt.show()

# %%
plt.figure(figsize =(20,12))
plt.subplot(2,3,1)
title15 = plt.bar(x4, runtime_2015)
plt.ylabel('Runtime in Minutes')
plt.xticks(x4, rotation = 'vertical')
plt.title('Runtimes of Top Grossing 2015 Movies')

plt.subplot(2,3,2)
title14 = plt.bar(x5, runtime_2014)
plt.ylabel('Runtime in Minutes')
plt.xticks(x5, rotation = 'vertical')
plt.title('Runtimes of Top Grossing 2014 Movies')
plt.savefig('Runtime 2014-2015.png')

# %%
plt.figure(figsize=(9,3))
x = ('2014', '2015', '2016', '2017', '2018')
y = (runtime_mean14, runtime_mean15, runtime_mean16, runtime_mean17, runtime_mean18)

plt.figure(figsize =(16, 8))
runtime = plt.bar(x, y )
plt.ylabel('Runtime in Minutes')
plt.xticks(x)
plt.title('Average Runtimes of Top Grossing Movies 2014-2018')

plt.savefig('Avg Runtime 2014-2018.png')

# %% [markdown]
# ## Average run times havent changed much in the past 5 years

# %% [markdown]
# ## Looking at ratings

# %%
all_movies = pd.read_csv('final.csv', index_col = 0)
all_movies.head()
# Out:
#        tconst                            title  runtime_minutes  \
# 15  tt0337692                      On the Road            124.0
# 18  tt0359950  The Secret Life of Walter Mitty            114.0
# 21  tt0365907      A Walk Among the Tombstones            114.0
# 22  tt0369610                   Jurassic World            124.0
# 23  tt0372538                              Spy            110.0
#
#                      genres  averagerating  numvotes release_date studio  \
# 15  Adventure,Drama,Romance            6.1   37886.0   2012-12-21    IFC
# 18   Adventure,Comedy,Drama            7.3  275300.0   2013-12-25    Fox
# 21       Action,Crime,Drama            6.5  105116.0   2014-09-19   Uni.
# 22  Action,Adventure,Sci-Fi            7.0  539338.0   2015-06-12   Uni.
# 23       Action,Crime,Drama            6.6      78.0   2011-08-09    Fox
#
#     domestic_gross foreign_gross
# 15        744000.0       8000000
# 18      58200000.0     129900000
# 21      26300000.0      26900000
# ...

# %%
top_rated18 = all_movies[(all_movies['release_date'] >= '2018')].sort_values(by ='averagerating', ascending = False)
top_rated18.head()
# Out:
#           tconst                       title  runtime_minutes  \
# 9205   tt2233624                         Kin             45.0
# 15196  tt4154756      Avengers: Infinity War            149.0
# 18625  tt6966692                  Green Book            130.0
# 13854  tt3576728  Bilal: A New Breed of Hero            105.0
# 5391   tt1727824           Bohemian Rhapsody            134.0
#
#                            genres  averagerating  numvotes release_date  \
# 9205                  Drama,Music            8.6      46.0   2018-08-31
# 15196     Action,Adventure,Sci-Fi            8.5  670926.0   2018-04-27
# 18625      Biography,Comedy,Drama            8.3  204972.0   2018-11-16
# 13854  Action,Adventure,Animation            8.0   16854.0   2018-02-02
# 5391        Biography,Drama,Music            8.0  345466.0   2018-11-02
#
#       studio  domestic_gross foreign_gross
# 9205     LGF       5700000.0       4300000
# 15196     BV     678800000.0       1,369.5
# ...

# %%
top_rated18.tail()
# Out:
#           tconst               title  runtime_minutes  \
# 19084  tt8097306       Nobody's Fool            110.0
# 15741  tt4477536  Fifty Shades Freed            105.0
# 4207   tt1620680   A Wrinkle in Time            109.0
# 17497  tt5691024           Show Dogs             92.0
# 17494  tt5690360         Slender Man             93.0
#
#                          genres  averagerating  numvotes release_date  \
# 19084      Comedy,Drama,Romance            4.6    3618.0   2018-11-02
# 15741    Drama,Romance,Thriller            4.5   43893.0   2018-02-09
# 4207   Adventure,Family,Fantasy            4.2   34888.0   2018-03-09
# 17497   Adventure,Comedy,Family            3.7    3458.0   2018-05-18
# 17494   Horror,Mystery,Thriller            3.2   19650.0   2018-08-10
#
#             studio  domestic_gross foreign_gross
# 19084         Par.      31700000.0       1800000
# 15741         Uni.     100400000.0     271500000
# 4207            BV     100500000.0      32200000
# ...

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Ratings')
ax1.boxplot(top_rated18['averagerating'], vert= False, showfliers = False)

fig1, ax2 = plt.subplots()
ax2.set_title('Domestic Gross')
ax2.boxplot(top_rated18['domestic_gross'],vert = False, showfliers = False)

fig1, ax3 = plt.subplots()
ax3.set_title('Runtime')
ax3.boxplot(top_rated18['runtime_minutes'], vert =False, showfliers = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e60be64320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e60be64a20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e60be641d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e60be710f0>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# ## Looking at Top rated movies and gross for specific studios from 2014-2018

# %%
## finding which studios were topping the domestic gross scene 
gross_2018['studio'].value_counts()

gross_2018['studio'].value_counts().plot(kind = "barh", title = "Top Grossing Studio Movies 2018")

plt.title("Top Grossing Studio Movies 2018")
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("Studio")
plt.ylabel("Number of Movies")
plt.savefig('studio2018.png')

# %%
gross_2017['studio'].value_counts()

gross_2017['studio'].value_counts().plot(kind = "barh", title = "Top Grossing Studio Movies 2017")

plt.title("Top Grossing Studio Movies 2017")
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("Studio")
plt.ylabel("Number of Movies")
plt.savefig('studio2017.png')

# %%
gross_2016['studio'].value_counts()

gross_2016['studio'].value_counts().plot(kind = "barh", title = "Top Grossing Studio Movies 2016")

plt.title("Top Grossing Studio Movies 2016")
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("Studio")
plt.ylabel("Number of Movies")
plt.savefig('studio2016.png')

# %%
gross_2015['studio'].value_counts().plot(kind = "barh", title = "Top Grossing Studio Movies 2015")

plt.title("Top Grossing Studio Movies 2015")
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("Studio")
plt.ylabel("Number of Movies")
plt.savefig('studio2015.png')

# %%
gross_2014['studio'].value_counts().plot(kind = "barh", title = "Top Grossing Studio Movies 2014")

plt.title("Top Grossing Studio Movies 2014")
plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("Studio")
plt.ylabel("Number of Movies")
plt.savefig('studio2014.png')

# %%
## Walt Disney Studios = BV
## Has been at the top for the past 5 years

# %% [markdown]
# ## Looking to see genres for all movies for BV for 2014-2018

# %%
top_BV_18 = all_movies[(all_movies['release_date'] >= '2018') & 
                                (all_movies['studio'] == 'BV') ].sort_values(by =['domestic_gross','averagerating'], ascending = False)
top_BV_18.head(10)
# Out:
#           tconst                               title  runtime_minutes  \
# 15196  tt4154756              Avengers: Infinity War            149.0
# 13939  tt3606756                       Incredibles 2            118.0
# 16701  tt5095030                Ant-Man and the Wasp            118.0
# 14420  tt3778644             Solo: A Star Wars Story            135.0
# 17691  tt5848272           Ralph Breaks the Internet            112.0
# 16594  tt5028340                Mary Poppins Returns            130.0
# 4207   tt1620680                   A Wrinkle in Time            109.0
# 17274  tt5523010  The Nutcracker and the Four Realms             99.0
#
#                            genres  averagerating  numvotes release_date  \
# 15196     Action,Adventure,Sci-Fi            8.5  670926.0   2018-04-27
# 13939  Action,Adventure,Animation            7.7  203510.0   2018-06-15
# 16701     Action,Adventure,Comedy            7.1  244024.0   2018-07-06
# ...

# %%
top_BV_17 = all_movies[(all_movies['release_date'] <= "2018") & (all_movies['release_date'] >= "2017") & 
                                (all_movies['studio'] == 'BV') ].sort_values(by =['domestic_gross','averagerating'], ascending = False)
top_BV_17.head(10)
# Out:
#           tconst                                             title  \
# 10933  tt2527336                          Star Wars: The Last Jedi
# 14698  tt3896198                    Guardians of the Galaxy Vol. 2
# 13633  tt3501632                                    Thor: Ragnarok
# 955    tt2380307                                              Coco
# 6078   tt1790809  Pirates of the Caribbean: Dead Men Tell No Tales
# 13938  tt3606752                                            Cars 3
# 15993  tt4629266                                     Born in China
#
#        runtime_minutes                      genres  averagerating  numvotes  \
# 10933            152.0    Action,Adventure,Fantasy            7.1  462903.0
# 14698            136.0     Action,Adventure,Comedy            7.7  482917.0
# 13633            130.0     Action,Adventure,Comedy            7.9  482995.0
# 955              105.0  Adventure,Animation,Comedy            8.4  277194.0
# ...

# %%
top_BV_16 = all_movies[(all_movies['release_date'] <= "2017") & (all_movies['release_date'] >= "2016") & 
                                (all_movies['studio'] == 'BV') ].sort_values(by =['domestic_gross','averagerating'], ascending = False)
top_BV_16.head(10)
# Out:
#           tconst                            title  runtime_minutes  \
# 14337  tt3748528     Rogue One: A Star Wars Story            133.0
# 9528   tt2277860                     Finding Dory             97.0
# 13618  tt3498820       Captain America: Civil War            147.0
# 12050  tt2948356                         Zootopia            108.0
# 1372   tt1211837                   Doctor Strange            115.0
# 11082  tt2567026  Alice Through the Looking Glass            113.0
# 14153  tt3691740                          The BFG            117.0
# 7736   tt2025690                 The Finest Hours            117.0
# 11011  tt2547584         The Light Between Oceans            133.0
# 15548  tt4341582                   Queen of Katwe            124.0
#
#                            genres  averagerating  numvotes release_date  \
# 14337     Action,Adventure,Sci-Fi            7.8  478592.0   2016-12-16
# 9528   Adventure,Animation,Comedy            7.3  213542.0   2016-06-17
# ...

# %%
top_BV_15 = all_movies[(all_movies['release_date'] <= "2016") & (all_movies['release_date'] >= "2015") & 
                                (all_movies['studio'] == 'BV') ].sort_values(by =['domestic_gross','averagerating'], ascending = False)
top_BV_15.head(10)
# Out:
#           tconst                    title  runtime_minutes  \
# 10366  tt2395427  Avengers: Age of Ultron            141.0
# 13696  tt3521164                    Moana            107.0
# 113    tt0478970                  Ant-Man            117.0
# 7467   tt1979388        The Good Dinosaur             93.0
# 7361   tt1964418             Tomorrowland            130.0
# 14114  tt3682448          Bridge of Spies            142.0
# 8324   tt2097298           McFarland, USA            129.0
# 14070  tt3660770           Monkey Kingdom             81.0
# 15267  tt4191054            Strange Magic             99.0
#
#                            genres  averagerating  numvotes release_date  \
# 10366     Action,Adventure,Sci-Fi            7.3  665594.0   2015-05-01
# 13696  Adventure,Animation,Comedy            7.6  224253.0   2015-11-13
# 113       Action,Adventure,Comedy            7.3  501213.0   2015-07-17
# 7467   Adventure,Animation,Comedy            6.7   91465.0   2015-11-25
# ...

# %%
top_BV_14 = all_movies[(all_movies['release_date'] <= "2015") & (all_movies['release_date'] >= "2014") & 
                                (all_movies['studio'] == 'BV') ].sort_values(by =['domestic_gross','averagerating'], ascending = False)
top_BV_14.head(10)
# Out:
#           tconst                                              title  \
# 7700   tt2015381                            Guardians of the Galaxy
# 6551   tt1843866                Captain America: The Winter Soldier
# 3817   tt1587310                                         Maleficent
# 9304   tt2245084                                         Big Hero 6
# 8858   tt2180411                                     Into the Woods
# 5089   tt1698641  Alexander and the Terrible, Horrible, No Good,...
# 12152  tt2980706                              Planes: Fire & Rescue
# 12150  tt2980648                           The Hundred-Foot Journey
# 9553   tt2281587                                Muppets Most Wanted
# 10135  tt2369135                                     Need for Speed
#
#        runtime_minutes                      genres  averagerating  numvotes  \
# 7700             121.0     Action,Adventure,Comedy            8.1  948394.0
# ...
